# %% [markdown]
# # Overview
# The notebook shows how to extract the segmentation map for the ships, augment the images and train a simple DNN model to detect them. A few additional tweaks like balancing the ship-count out a little better have been done.

# %% [markdown]
# ## Importing Packages

# %%
import os
import numpy as np 
import pandas as pd 
from skimage.io import imread
import matplotlib.pyplot as plt
from skimage.segmentation import mark_boundaries
from skimage.util.montage import montage2d as montage
import gc; gc.enable() 
from skimage.morphology import label
from sklearn.model_selection import train_test_split

# %%
ship_dir = '../input'
train_image_dir = os.path.join(ship_dir, 'train_v2')
test_image_dir = os.path.join(ship_dir, 'test_v2')
model_dir = '/kaggle/working/Unet_model'

# %% [markdown]
# ## Model Parameters
# We might want to adjust these later (or do some hyperparameter optimizations)

# %%
BATCH_SIZE = 48
NB_EPOCHS = 99
VALID_IMG_COUNT = 900
MAX_TRAIN_STEPS = 9
IMG_SCALING = (3, 3)
BATCH_NORMALIZATION = None
AUGMENT_BRIGHTNESS = False

# %%
def multi_rle_encode(img):
    labels = label(img[:, :, 0])
    return [rle_encode(labels==k) for k in np.unique(labels[labels>0])]

def rle_encode(img):
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)):
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list):
    all_masks = np.zeros((768, 768), dtype = np.int16)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks += rle_decode(mask)
    return np.expand_dims(all_masks, -1)

# %%
masks = pd.read_csv(os.path.join('../input/',
                                 'train_ship_segmentations_v2.csv'))
print(masks.shape[0], 'masks found')
print(masks['ImageId'].value_counts().shape[0])
masks.head()
# Out:
# 231723 masks found
# 192556
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  0001124c7.jpg                                                NaN
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...

# %% [markdown]
# # Make sure encode/decode works
# Given the process
# $$  RLE_0 \stackrel{Decode}{\longrightarrow} \textrm{Image}_0 \stackrel{Encode}{\longrightarrow} RLE_1 \stackrel{Decode}{\longrightarrow} \textrm{Image}_1 $$
# We want to check if/that
# $ \textrm{Image}_0 \stackrel{?}{=} \textrm{Image}_1 $
# We could check the RLEs as well but that is more tedious. Also depending on how the objects have been labeled we might have different counts.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
rle_0 = masks.query('ImageId=="00021ddc3.jpg"')['EncodedPixels']
img_0 = masks_as_image(rle_0)
ax1.imshow(img_0[:, :, 0])
ax1.set_title('Image$_0$')
rle_1 = multi_rle_encode(img_0)
img_1 = masks_as_image(rle_1)
ax2.imshow(img_1[:, :, 0])
ax2.set_title('Image$_1$')
print('Check Decoding->Encoding',
      'RLE_0:', len(rle_0), '->',
      'RLE_1:', len(rle_1))
# Out:
# Check Decoding->Encoding RLE_0: 9 -> RLE_1: 4

# %% [markdown]
# # Split into training and validation groups
# We stratify by the number of boats appearing so we have nice balances in each set

# %%
masks['ships'] = masks['EncodedPixels'].map(lambda c_row: 1 if isinstance(c_row, str) else 0)
unique_img_ids = masks.groupby('ImageId').agg({'ships': 'sum'}).reset_index()
unique_img_ids['has_ship'] = unique_img_ids['ships'].map(lambda x: 1.0 if x>0 else 0.0)
# some files are too small/corrupt
unique_img_ids['file_size_kb'] = unique_img_ids['ImageId'].map(lambda c_img_id: 
                                                               os.stat(os.path.join(train_image_dir, 
                                                                                    c_img_id)).st_size/1024)
unique_img_ids = unique_img_ids[unique_img_ids['file_size_kb']>50] # keep only 50kb files
unique_img_ids['file_size_kb'].hist()
masks.drop(['ships'], axis=1, inplace=True)
unique_img_ids.sample(5)
# Out:
#               ImageId  ships  has_ship  file_size_kb
# 152087  ca4899b4d.jpg      0       0.0     76.066406
# 188431  fa9d579c1.jpg      1       1.0    195.210938
# 181070  f0d2d1a57.jpg      0       0.0    123.777344
# 138027  b76ca27cf.jpg      0       0.0    221.459961
# 91561   799b304fe.jpg      0       0.0    115.220703

# %% [markdown]
# # Undersample Empty Images
# Here we undersample the empty images to get a better balanced group with more ships to try and segment

# %%
SAMPLES_PER_GROUP = 2000
balanced_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)
balanced_df['ships'].hist(bins=balanced_df['ships'].max()+1)
print(balanced_df.shape[0], 'masks')
# Out:
# 12788 masks

# %%
train_ids, valid_ids = train_test_split(balanced_df, 
                 test_size = 0.2, 
                 stratify = balanced_df['ships'])
train_df = pd.merge(masks, train_ids)
valid_df = pd.merge(masks, valid_ids)
print(train_df.shape[0], 'training masks')
print(valid_df.shape[0], 'validation masks')
# Out:
# 35364 training masks
# 8838 validation masks

# %% [markdown]
# ### Examine Number of Ship Images
# Here we examine how often ships appear and replace the ones without any ships with 0

# %%
train_df['ships'].hist()

# %%
# train_df['grouped_ship_count'] = train_df['ships'].map(lambda x: (x+1)//2).clip(0, 7)
# def sample_ships(in_df, base_rep_val=1500):
#     if in_df['ships'].values[0]==0:
#         return in_df.sample(base_rep_val//3) # even more strongly undersample no ships
#     else:
#         return in_df.sample(base_rep_val, replace=(in_df.shape[0]<base_rep_val))
    
# balanced_train_df = train_df.groupby('grouped_ship_count').apply(sample_ships)
# balanced_train_df['ships'].hist(bins=np.arange(10))

# %%
# print(balanced_train_df.shape)

# %% [markdown]
# # Decode all the RLEs into Images
# We make a generator to produce batches of images

# %%
def make_image_gen(in_df, batch_size = BATCH_SIZE):
    all_batches = list(in_df.groupby('ImageId'))
    out_rgb = []
    out_mask = []
    while True:
        np.random.shuffle(all_batches)
        for c_img_id, c_masks in all_batches:
            rgb_path = os.path.join(train_image_dir, c_img_id)
            c_img = imread(rgb_path)
            c_mask = masks_as_image(c_masks['EncodedPixels'].values)
            if IMG_SCALING is not None:
                c_img = c_img[::IMG_SCALING[0], ::IMG_SCALING[1]]
                c_mask = c_mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
            out_rgb += [c_img]
            out_mask += [c_mask]
            if len(out_rgb)>=batch_size:
                yield np.stack(out_rgb, 0)/255.0, np.stack(out_mask, 0)
                out_rgb, out_mask=[], []

# %%
train_gen = make_image_gen(train_df)
print(train_gen)
train_x, train_y = next(train_gen)
print('x', train_x.shape, train_x.min(), train_x.max())
print('y', train_y.shape, train_y.min(), train_y.max())
# Out:
# <generator object make_image_gen at 0x7984100364c0>
# x (64, 256, 256, 3) 0.0 1.0
# y (64, 256, 256, 1) 0 1

# %%
montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (30, 10))
batch_rgb = montage_rgb(train_x)
batch_seg = montage(train_y[:, :, :, 0])
ax1.imshow(batch_rgb)
ax1.set_title('Images')
ax2.imshow(batch_seg)
ax2.set_title('Segmentations')
ax3.imshow(mark_boundaries(batch_rgb, 
                           batch_seg.astype(int)))
ax3.set_title('Outlined Ships')
fig.savefig('overview.png')

# %% [markdown]
# # Make the Validation Set

# %%
valid_x, valid_y = next(make_image_gen(valid_df, VALID_IMG_COUNT))
print(valid_x.shape, valid_y.shape)
# Out:
# (900, 256, 256, 3) (900, 256, 256, 1)

# %%
gc.collect()
# Out:
# 170135

# %%
from keras.preprocessing.image import ImageDataGenerator
dg_args = dict(featurewise_center = False, 
                  samplewise_center = False,
                  rotation_range = 45, 
                  width_shift_range = 0.1, 
                  height_shift_range = 0.1, 
                  shear_range = 0.01,
                  zoom_range = [0.9, 1.25],  
                  horizontal_flip = True, 
                  vertical_flip = True,
                  fill_mode = 'reflect',
                   data_format = 'channels_last')
# brightness can be problematic since it seems to change the labels differently from the images 
if AUGMENT_BRIGHTNESS:
    dg_args[' brightness_range'] = [0.5, 1.5]
image_gen = ImageDataGenerator(**dg_args)

if AUGMENT_BRIGHTNESS:
    dg_args.pop('brightness_range')
label_gen = ImageDataGenerator(**dg_args)

def create_aug_gen(in_gen, seed = None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    for in_x, in_y in in_gen:
        seed = np.random.choice(range(9999))
        # keep the seeds syncronized otherwise the augmentation to the images is different from the masks
        g_x = image_gen.flow(255*in_x, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)
        g_y = label_gen.flow(in_y, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)

        yield next(g_x)/255.0, next(g_y)

# %% [markdown]
# ## Build Unet Model using ResNet50 as Encoder

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Conv2DTranspose, Concatenate, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50, VGG16, VGG19, DenseNet121

# %%
def conv_block(inputs, no_filters):
    x = Conv2D(no_filters, 3, padding="same")(inputs)
    if BATCH_NORMALIZATION is not None:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(no_filters, 3, padding="same")(x)
    if BATCH_NORMALIZATION is not None:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    return x

def decoder_block(inputs, skip_features, no_filters):
    x = Conv2DTranspose(no_filters, (2, 2), strides=2, padding="same")(inputs)

    x = Concatenate(axis=3)([skip_features, x])
    x = conv_block(x, no_filters)
    return x

# %%
def build_resnet50_unet(input_shape):
    """ Input """
    input_imgs = Input(input_shape, name = 'RGB_Input')

    """ Pretrained ResNet50 Model """
    resnet50 = ResNet50(include_top=False, weights="imagenet", input_tensor=input_imgs)

    for layer in resnet50.layers:
        layer.trainable = False

    """ Skip Features """
    e1 = input_imgs  # (265, 265, 3)
    e2 = resnet50.layers[4].output # (128, 128, 64)
    e3 = resnet50.layers[38].output # (64, 64, 265)
    e4 = resnet50.layers[80].output # (32, 32, 512)

    """ Bridge """
    b1 = resnet50.layers[142].output # (16, 16, 1024)

    """ Decoder """
    d1 = decoder_block(b1, e4, 512)
    d2 = decoder_block(d1, e3, 256)
    d3 = decoder_block(d2, e2, 128)
    d4 = decoder_block(d3, e1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(input_imgs, outputs)
    return model

# %%
s1 = resnet50.layers[142].output
s2 = resnet50.layers[80].output
s3 = resnet50.layers[38].output
s4 = resnet50.layers[4].output

print(s1.shape, s2.shape, s3.shape, s4.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a7736025c479> in <module>
# ----> 1 s1 = resnet50.layers[142].output
#       2 s2 = resnet50.layers[80].output
#       3 s3 = resnet50.layers[38].output
#       4 s4 = resnet50.layers[4].output
#       5
#
# NameError: name 'resnet50' is not defined

# %% [markdown]
# ## Build Unet Model using VGG19 as Encoder

# %%
def build_vgg19_unet(input_shape):
    """ Input """
    input_imgs = Input(train_x.shape[1:], name = 'RGB_Input')

    """ Pretrained ResNet50 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=input_imgs)

#     for layer in vgg19.layers:
#         layer.trainable = False

    """ Skip Features """
    e1 = vgg19.layers[2].output # (265, 265, 64)
    e2 = vgg19.layers[5].output # (128, 128, 128)
    e3 = vgg19.layers[10].output # (64, 64, 265)
    e4 = vgg19.layers[15].output # (32, 32, 512)

    """ Bridge """
    b1 = vgg19.layers[20].output # (16, 16, 512)

    """ Decoder """
    d1 = decoder_block(b1, e4, 64)
    d2 = decoder_block(d1, e3, 32)
    d3 = decoder_block(d2, e2, 16)
    d4 = decoder_block(d3, e1, 8)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(input_imgs, outputs)
    return model

# %%
n1 = vgg19.layers[2].name
n2 = vgg19.layers[5].name
n3 = vgg19.layers[10].name
n4 = vgg19.layers[15].name
n5 = vgg19.layers[20].name

print(n1, n2, n3, n4, n5)

# %%
model = build_vgg19_unet(train_x.shape[1:])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# RGB_Input (InputLayer)          (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 256, 64) 1792        RGB_Input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 256, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 128, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 128, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 128, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 64, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 64, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 32, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 32, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 16, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 32, 32, 64)   131136      block5_conv4[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 576)  0           block4_conv4[0][0]
#                                                                  conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 64)   331840      concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 64)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 64, 64, 32)   8224        activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 288)  0           block3_conv4[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 32)   82976       concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 32)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 32)   9248        activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 128, 128, 16) 2064        activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 144 0           block2_conv2[0][0]
#                                                                  conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 16) 20752       concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 16) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 16) 2320        activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 128, 16) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 256, 256, 8)  520         activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 72) 0           block1_conv2[0][0]
#                                                                  conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 8)  5192        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 8)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 8)  584         activation_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 256, 256, 8)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 1)  9           activation_23[0][0]
# ==================================================================================================
# Total params: 20,656,177
# Trainable params: 20,656,177
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

## intersection over union
def IoU(y_true, y_pred, eps=1e-6):
    if np.max(y_true) == 0.0:
        return IoU(1-y_true, 1-y_pred) ## empty image; calc IoU of zeros
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3]) - intersection
    return -K.mean( (intersection + eps) / (union + eps), axis=0)

def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

def combo_loss(y_true, y_pred):
    return 1e-3 * binary_crossentropy(y_true, y_pred) - dice_coef(y_true, y_pred)

def jaccard_index(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3]) - intersection
    return -K.mean((intersection + smooth) / (union + smooth), axis=0)

model.compile(optimizer='adam', loss=IoU, metrics=[dice_coef, 'binary_accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau

if not os.path.isdir(model_dir):
    os.mkdir(model_dir)
    
weight_path="{}_weights.best.hdf5".format(model_dir)

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.33, 
                                   patience=1, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=0, min_lr=1e-8)
early = EarlyStopping(monitor="val_loss", 
                      mode="min",
                      verbose = 2,
                      patience=10) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
step_count = min(MAX_TRAIN_STEPS, train_df.shape[0]//BATCH_SIZE)
aug_gen = create_aug_gen(make_image_gen(train_df))
loss_history = [model.fit_generator(aug_gen, 
                             steps_per_epoch=step_count, 
                             epochs=NB_EPOCHS, 
                             validation_data=(valid_x, valid_y),
                             callbacks=callbacks_list,
                             workers=1 # the generator is not very thread safe
                                       )]
# Out:
# Epoch 1/99
# 8/9 [=========================>....] - ETA: 2s - loss: -0.0162 - dice_coef: 0.0304 - binary_accuracy: 0.9751
# Epoch 00001: val_loss improved from inf to -0.05037, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 34s 4s/step - loss: -0.0250 - dice_coef: 0.0445 - binary_accuracy: 0.9738 - val_loss: -0.0504 - val_dice_coef: 0.0878 - val_binary_accuracy: 0.9248
# Epoch 2/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.0637 - dice_coef: 0.1080 - binary_accuracy: 0.8980
# Epoch 00002: val_loss improved from -0.05037 to -0.12255, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 18s 2s/step - loss: -0.0676 - dice_coef: 0.1123 - binary_accuracy: 0.8870 - val_loss: -0.1226 - val_dice_coef: 0.1801 - val_binary_accuracy: 0.7399
# Epoch 3/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.1618 - dice_coef: 0.2467 - binary_accuracy: 0.8630
# Epoch 00003: val_loss improved from -0.12255 to -0.12714, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.1607 - dice_coef: 0.2476 - binary_accuracy: 0.8744 - val_loss: -0.1271 - val_dice_coef: 0.1863 - val_binary_accuracy: 0.7862
# Epoch 4/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.1731 - dice_coef: 0.2904 - binary_accuracy: 0.9308
# Epoch 00004: val_loss improved from -0.12714 to -0.21152, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.1807 - dice_coef: 0.2995 - binary_accuracy: 0.9368 - val_loss: -0.2115 - val_dice_coef: 0.3179 - val_binary_accuracy: 0.9197
# Epoch 5/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2146 - dice_coef: 0.3566 - binary_accuracy: 0.9277
# Epoch 00005: val_loss improved from -0.21152 to -0.23790, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2094 - dice_coef: 0.3549 - binary_accuracy: 0.9288 - val_loss: -0.2379 - val_dice_coef: 0.3658 - val_binary_accuracy: 0.9362
# Epoch 6/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2454 - dice_coef: 0.3738 - binary_accuracy: 0.9730
# Epoch 00006: val_loss improved from -0.23790 to -0.26501, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2434 - dice_coef: 0.3775 - binary_accuracy: 0.9734 - val_loss: -0.2650 - val_dice_coef: 0.4283 - val_binary_accuracy: 0.9745
# Epoch 7/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2463 - dice_coef: 0.3973 - binary_accuracy: 0.9661
# Epoch 00007: val_loss improved from -0.26501 to -0.27501, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2427 - dice_coef: 0.3915 - binary_accuracy: 0.9659 - val_loss: -0.2750 - val_dice_coef: 0.4206 - val_binary_accuracy: 0.9689
# Epoch 8/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2273 - dice_coef: 0.3778 - binary_accuracy: 0.9653
# Epoch 00008: val_loss did not improve from -0.27501
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00033000001567415896.
# 9/9 [==============================] - 21s 2s/step - loss: -0.2273 - dice_coef: 0.3781 - binary_accuracy: 0.9672 - val_loss: -0.2541 - val_dice_coef: 0.4276 - val_binary_accuracy: 0.9871
# Epoch 9/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2562 - dice_coef: 0.4056 - binary_accuracy: 0.9768
# Epoch 00009: val_loss improved from -0.27501 to -0.27958, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2556 - dice_coef: 0.4052 - binary_accuracy: 0.9761 - val_loss: -0.2796 - val_dice_coef: 0.4222 - val_binary_accuracy: 0.9674
# Epoch 10/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2579 - dice_coef: 0.4137 - binary_accuracy: 0.9714
# Epoch 00010: val_loss did not improve from -0.27958
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010890000325161964.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2591 - dice_coef: 0.4254 - binary_accuracy: 0.9734 - val_loss: -0.2793 - val_dice_coef: 0.4460 - val_binary_accuracy: 0.9814
# Epoch 11/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2619 - dice_coef: 0.4270 - binary_accuracy: 0.9752
# Epoch 00011: val_loss improved from -0.27958 to -0.28970, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2620 - dice_coef: 0.4223 - binary_accuracy: 0.9731 - val_loss: -0.2897 - val_dice_coef: 0.4419 - val_binary_accuracy: 0.9732
# Epoch 12/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2716 - dice_coef: 0.4193 - binary_accuracy: 0.9727
# Epoch 00012: val_loss improved from -0.28970 to -0.29265, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2777 - dice_coef: 0.4264 - binary_accuracy: 0.9729 - val_loss: -0.2926 - val_dice_coef: 0.4505 - val_binary_accuracy: 0.9732
# Epoch 13/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2707 - dice_coef: 0.4330 - binary_accuracy: 0.9760
# Epoch 00013: val_loss did not improve from -0.29265
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.5936999920522795e-05.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2779 - dice_coef: 0.4465 - binary_accuracy: 0.9771 - val_loss: -0.2906 - val_dice_coef: 0.4681 - val_binary_accuracy: 0.9820
# Epoch 14/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2907 - dice_coef: 0.4485 - binary_accuracy: 0.9799
# Epoch 00014: val_loss did not improve from -0.29265
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.185920958960196e-05.
# 9/9 [==============================] - 21s 2s/step - loss: -0.2918 - dice_coef: 0.4436 - binary_accuracy: 0.9800 - val_loss: -0.2919 - val_dice_coef: 0.4602 - val_binary_accuracy: 0.9796
# Epoch 15/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2697 - dice_coef: 0.4117 - binary_accuracy: 0.9758
# Epoch 00015: val_loss improved from -0.29265 to -0.29390, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2720 - dice_coef: 0.4217 - binary_accuracy: 0.9769 - val_loss: -0.2939 - val_dice_coef: 0.4630 - val_binary_accuracy: 0.9793
# Epoch 16/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2862 - dice_coef: 0.4617 - binary_accuracy: 0.9785
# Epoch 00016: val_loss improved from -0.29390 to -0.29605, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2892 - dice_coef: 0.4659 - binary_accuracy: 0.9785 - val_loss: -0.2961 - val_dice_coef: 0.4668 - val_binary_accuracy: 0.9791
# Epoch 17/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2665 - dice_coef: 0.4616 - binary_accuracy: 0.9796
# Epoch 00017: val_loss improved from -0.29605 to -0.29622, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2661 - dice_coef: 0.4537 - binary_accuracy: 0.9786 - val_loss: -0.2962 - val_dice_coef: 0.4638 - val_binary_accuracy: 0.9779
# Epoch 18/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2730 - dice_coef: 0.4237 - binary_accuracy: 0.9757
# Epoch 00018: val_loss improved from -0.29622 to -0.29681, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2720 - dice_coef: 0.4213 - binary_accuracy: 0.9756 - val_loss: -0.2968 - val_dice_coef: 0.4655 - val_binary_accuracy: 0.9785
# Epoch 19/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2694 - dice_coef: 0.4341 - binary_accuracy: 0.9781
# Epoch 00019: val_loss improved from -0.29681 to -0.29741, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2688 - dice_coef: 0.4383 - binary_accuracy: 0.9789 - val_loss: -0.2974 - val_dice_coef: 0.4691 - val_binary_accuracy: 0.9798
# Epoch 20/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2739 - dice_coef: 0.4502 - binary_accuracy: 0.9772
# Epoch 00020: val_loss improved from -0.29741 to -0.29780, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2777 - dice_coef: 0.4513 - binary_accuracy: 0.9776 - val_loss: -0.2978 - val_dice_coef: 0.4723 - val_binary_accuracy: 0.9810
# Epoch 21/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2855 - dice_coef: 0.4538 - binary_accuracy: 0.9803
# Epoch 00021: val_loss improved from -0.29780 to -0.29809, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2891 - dice_coef: 0.4530 - binary_accuracy: 0.9801 - val_loss: -0.2981 - val_dice_coef: 0.4755 - val_binary_accuracy: 0.9821
# Epoch 22/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2688 - dice_coef: 0.4315 - binary_accuracy: 0.9784
# Epoch 00022: val_loss improved from -0.29809 to -0.29824, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2616 - dice_coef: 0.4233 - binary_accuracy: 0.9784 - val_loss: -0.2982 - val_dice_coef: 0.4751 - val_binary_accuracy: 0.9820
# Epoch 23/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2656 - dice_coef: 0.4477 - binary_accuracy: 0.9793
# Epoch 00023: val_loss improved from -0.29824 to -0.29852, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 21s 2s/step - loss: -0.2606 - dice_coef: 0.4475 - binary_accuracy: 0.9791 - val_loss: -0.2985 - val_dice_coef: 0.4747 - val_binary_accuracy: 0.9818
# Epoch 24/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2774 - dice_coef: 0.4188 - binary_accuracy: 0.9765
# Epoch 00024: val_loss did not improve from -0.29852
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.913539212589967e-06.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2761 - dice_coef: 0.4235 - binary_accuracy: 0.9770 - val_loss: -0.2984 - val_dice_coef: 0.4732 - val_binary_accuracy: 0.9817
# Epoch 25/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2623 - dice_coef: 0.4280 - binary_accuracy: 0.9790
# Epoch 00025: val_loss improved from -0.29852 to -0.29881, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2708 - dice_coef: 0.4364 - binary_accuracy: 0.9795 - val_loss: -0.2988 - val_dice_coef: 0.4749 - val_binary_accuracy: 0.9821
# Epoch 26/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2939 - dice_coef: 0.4655 - binary_accuracy: 0.9810
# Epoch 00026: val_loss improved from -0.29881 to -0.29918, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2872 - dice_coef: 0.4558 - binary_accuracy: 0.9809 - val_loss: -0.2992 - val_dice_coef: 0.4759 - val_binary_accuracy: 0.9822
# Epoch 27/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2992 - dice_coef: 0.4765 - binary_accuracy: 0.9838
# Epoch 00027: val_loss improved from -0.29918 to -0.29951, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2939 - dice_coef: 0.4766 - binary_accuracy: 0.9831 - val_loss: -0.2995 - val_dice_coef: 0.4764 - val_binary_accuracy: 0.9822
# Epoch 28/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2731 - dice_coef: 0.4448 - binary_accuracy: 0.9798
# Epoch 00028: val_loss improved from -0.29951 to -0.29975, saving model to /kaggle/working/Unet_model_weights.best.hdf5
# 9/9 [==============================] - 20s 2s/step - loss: -0.2752 - dice_coef: 0.4441 - binary_accuracy: 0.9804 - val_loss: -0.2998 - val_dice_coef: 0.4769 - val_binary_accuracy: 0.9823
# Epoch 29/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2827 - dice_coef: 0.4600 - binary_accuracy: 0.9828
# Epoch 00029: val_loss improved from -0.29975 to -0.29980, saving model to /kaggle/working/Unet_model_weights.best.hdf5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.2914679791720119e-06.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2903 - dice_coef: 0.4607 - binary_accuracy: 0.9830 - val_loss: -0.2998 - val_dice_coef: 0.4766 - val_binary_accuracy: 0.9822
# Epoch 30/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2978 - dice_coef: 0.4799 - binary_accuracy: 0.9812
# Epoch 00030: val_loss did not improve from -0.29980
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.2618441511876884e-07.
# 9/9 [==============================] - 19s 2s/step - loss: -0.2990 - dice_coef: 0.4850 - binary_accuracy: 0.9820 - val_loss: -0.2998 - val_dice_coef: 0.4762 - val_binary_accuracy: 0.9820
# Epoch 31/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.3081 - dice_coef: 0.4885 - binary_accuracy: 0.9831
# Epoch 00031: val_loss did not improve from -0.29980
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.4064085661402716e-07.
# 9/9 [==============================] - 20s 2s/step - loss: -0.3042 - dice_coef: 0.4896 - binary_accuracy: 0.9833 - val_loss: -0.2998 - val_dice_coef: 0.4762 - val_binary_accuracy: 0.9820
# Epoch 32/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2664 - dice_coef: 0.4388 - binary_accuracy: 0.9778
# Epoch 00032: val_loss did not improve from -0.29980
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.641148052542121e-08.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2675 - dice_coef: 0.4381 - binary_accuracy: 0.9768 - val_loss: -0.2998 - val_dice_coef: 0.4762 - val_binary_accuracy: 0.9820
# Epoch 33/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2783 - dice_coef: 0.4334 - binary_accuracy: 0.9784
# Epoch 00033: val_loss did not improve from -0.29980
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.5315788104430796e-08.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2864 - dice_coef: 0.4423 - binary_accuracy: 0.9793 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 34/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2730 - dice_coef: 0.4283 - binary_accuracy: 0.9783
# Epoch 00034: val_loss did not improve from -0.29980
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-08.
# 9/9 [==============================] - 20s 2s/step - loss: -0.2720 - dice_coef: 0.4267 - binary_accuracy: 0.9777 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 35/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2667 - dice_coef: 0.4266 - binary_accuracy: 0.9814
# Epoch 00035: val_loss did not improve from -0.29980
# 9/9 [==============================] - 20s 2s/step - loss: -0.2642 - dice_coef: 0.4233 - binary_accuracy: 0.9810 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 36/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2889 - dice_coef: 0.4512 - binary_accuracy: 0.9806
# Epoch 00036: val_loss did not improve from -0.29980
# 9/9 [==============================] - 20s 2s/step - loss: -0.2848 - dice_coef: 0.4520 - binary_accuracy: 0.9811 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 37/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2784 - dice_coef: 0.4711 - binary_accuracy: 0.9792
# Epoch 00037: val_loss did not improve from -0.29980
# 9/9 [==============================] - 20s 2s/step - loss: -0.2833 - dice_coef: 0.4700 - binary_accuracy: 0.9791 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 38/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.3137 - dice_coef: 0.4832 - binary_accuracy: 0.9825
# Epoch 00038: val_loss did not improve from -0.29980
# 9/9 [==============================] - 20s 2s/step - loss: -0.3077 - dice_coef: 0.4777 - binary_accuracy: 0.9827 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 39/99
# 8/9 [=========================>....] - ETA: 1s - loss: -0.2647 - dice_coef: 0.4457 - binary_accuracy: 0.9796
# Epoch 00039: val_loss did not improve from -0.29980
# 9/9 [==============================] - 20s 2s/step - loss: -0.2704 - dice_coef: 0.4445 - binary_accuracy: 0.9800 - val_loss: -0.2998 - val_dice_coef: 0.4761 - val_binary_accuracy: 0.9820
# Epoch 00039: early stopping

# %%
def show_loss(loss_history):
    epich = np.cumsum(np.concatenate(
        [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(22, 10))
    _ = ax1.plot(epich,
                 np.concatenate([mh.history['loss'] for mh in loss_history]),
                 'b-',
                 epich, np.concatenate(
            [mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')

    _ = ax2.plot(epich, np.concatenate(
        [mh.history['dice_coef'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_dice_coef'] for mh in loss_history]),
                     'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('DICE')
    
    _ = ax3.plot(epich, np.concatenate(
        [mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_binary_accuracy'] for mh in loss_history]),
                     'r-')
    ax3.legend(['Training', 'Validation'])
    ax3.set_title('Binary Accuracy (%)')
    plt.savefig('losses.png')

show_loss(loss_history)

# %% [markdown]
# ## Taking Insight about Training and Validation Results

# %%
fig, m_axs = plt.subplots(20, 3, figsize = (10, 40))
[c_ax.axis('off') for c_ax in m_axs.flatten()]
valid_imgs = list(valid_df.groupby('ImageId'))
for (ax1, ax2, ax3), (c_img_name, c_masks) in zip(m_axs, valid_imgs):
    c_path = os.path.join(train_image_dir, c_img_name)
    c_img = imread(c_path)
    img = np.expand_dims(c_img, 0)/255.0
    if IMG_SCALING is not None:
        img = img[:, ::IMG_SCALING[0], ::IMG_SCALING[1]]
    seg = model.predict(img)
    mask = masks_as_image(c_masks['EncodedPixels'].values)
    if IMG_SCALING is not None:
        mask = mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
    ax1.imshow(img[0])
    ax1.set_title('Image')
    ax2.imshow(seg[0, :, :, 0], vmin = 0, vmax = 1)
    ax2.set_title('Prediction')
    ax3.imshow(mask[:, :, 0])
    ax3.set_title('Ground Truth')
plt.savefig('image_pred_ground_truth.png')

# %%
model.load_weights(weight_path)
model.save('Unet_model.h5')

# %%
pred_y = model.predict(valid_x)
print(pred_y.shape, pred_y.min(), pred_y.max(), pred_y.mean())
# Out:
# (900, 256, 256, 1) 2.5944202e-27 1.0 0.02001776

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 10))
ax.hist(pred_y.ravel(), np.linspace(0, 1, 10))
ax.set_xlim(0, 1)
ax.set_yscale('log', nonposy='clip')

# %% [markdown]
# # Run the test data

# %%
test_paths = os.listdir(test_image_dir)
print(len(test_paths), 'test images found')
# Out:
# 15606 test images found

# %%
fig, m_axs = plt.subplots(20, 2, figsize = (10, 40))
[c_ax.axis('off') for c_ax in m_axs.flatten()]
for (ax1, ax2), c_img_name in zip(m_axs, test_paths):
    c_path = os.path.join(test_image_dir, c_img_name)
    c_img = imread(c_path)
    first_img = np.expand_dims(c_img, 0)/255.0
    if IMG_SCALING is not None:
        first_img = first_img[:, ::IMG_SCALING[0], ::IMG_SCALING[1]]
    first_seg = model.predict(first_img)
    ax1.imshow(first_img[0])
    ax1.set_title('Image')
    ax2.imshow(first_seg[0, :, :, 0], vmin = 0, vmax = 1)
    ax2.set_title('Prediction')
fig.savefig('test_predictions.png')
